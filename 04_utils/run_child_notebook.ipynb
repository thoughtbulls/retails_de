# %%
dbutils.notebook.run("notebook_parameters", 600, 
                     {"dept": "Sales",
                      "is_active": 'Y'
                      
                      })
# emp_df = spark.read.table("emp")

# %%
dbutils.notebook.run("notebook_parameters", 600, 
                     {"dept": "Marketing", "is_active": 'Y'})
