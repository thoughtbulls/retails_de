# %%
# %sql
CREATE TABLE IF NOT EXISTS retails.silver.departments_cdc (

    -- Business Columns
    department_id BIGINT,
    department_name STRING,

    -- CDC Event Metadata
    op STRING,                     -- INSERT / UPDATE / DELETE
    event_ts TIMESTAMP,
    is_deleted BOOLEAN,

    -- CDC Tracking
    -- change_version BIGINT,
    -- change_type STRING,

    -- Source Metadata
    source_system STRING,
    source_file_name STRING,

    -- Pipeline Metadata
    ingestion_ts TIMESTAMP,
    ingestion_dt DATE,
    batch_id INTEGER,
    run_id STRING,

    -- Optional Tracking
    record_hash STRING

)
USING DELTA;

# %%
# %sql
CREATE TABLE IF NOT EXISTS retails.silver.departments_cleaned (

    department_id BIGINT,
    department_name STRING,

    op STRING,
    is_deleted BOOLEAN,

    ingestion_ts TIMESTAMP,
    ingestion_dt DATE,

    source_system STRING,
    source_file_name STRING,

    batch_id BIGINT,
    run_id STRING,

    record_hash STRING,

    created_ts TIMESTAMP,
    updated_ts TIMESTAMP

)
USING DELTA;

# %%
# %sql
CREATE TABLE IF NOT EXISTS retails.silver.departments_quarantine (

    quarantine_id STRING,

    department_id STRING,
    department_name STRING,

    op STRING,

    _rescued_data STRING,
    _corrupt_record STRING,

    quarantine_reason STRING,
    quarantine_status STRING,

    ingestion_ts TIMESTAMP,
    ingestion_dt DATE,

    source_system STRING,
    source_file_name STRING,

    batch_id BIGINT,
    run_id STRING,

    created_ts TIMESTAMP,
    updated_ts TIMESTAMP,
    reprocessed_at TIMESTAMP

)
USING DELTA;

# %%
# %sql
CREATE TABLE IF NOT EXISTS retails.silver.categories_cdc (

    -- Business Columns
    category_id BIGINT,
    category_department_id BIGINT,
    category_name STRING,

    -- CDC Event Metadata
    op STRING,                     -- INSERT / UPDATE / DELETE
    event_ts TIMESTAMP,
    is_deleted BOOLEAN,

    -- CDC Tracking
    -- change_version BIGINT,
    -- change_type STRING,

    -- Source Metadata
    source_system STRING,
    source_file_name STRING,

    -- Pipeline Metadata
    ingestion_ts TIMESTAMP,
    ingestion_dt DATE,
    batch_id INTEGER,
    run_id STRING,

    -- Optional Tracking
    record_hash STRING

)
USING DELTA;

# %%
# %sql
CREATE TABLE IF NOT EXISTS retails.silver.categories_cleaned (

    category_id BIGINT,
    category_department_id BIGINT,
    category_name STRING,

    op STRING,
    is_deleted BOOLEAN,

    ingestion_ts TIMESTAMP,
    ingestion_dt DATE,

    source_system STRING,
    source_file_name STRING,

    batch_id BIGINT,
    run_id STRING,

    record_hash STRING,

    created_ts TIMESTAMP,
    updated_ts TIMESTAMP

)
USING DELTA;

# %%
# %sql
CREATE TABLE IF NOT EXISTS retails.silver.categories_quarantine (

    quarantine_id STRING,

    category_id STRING,
    category_department_id STRING,
    category_name STRING,

    op STRING,

    _rescued_data STRING,
    _corrupt_record STRING,

    quarantine_reason STRING,
    quarantine_status STRING,

    ingestion_ts TIMESTAMP,
    ingestion_dt DATE,

    source_system STRING,
    source_file_name STRING,

    batch_id BIGINT,
    run_id STRING,

    created_ts TIMESTAMP,
    updated_ts TIMESTAMP,
    reprocessed_at TIMESTAMP

)
USING DELTA;

# %%
# %sql
CREATE TABLE IF NOT EXISTS retails.silver.products_cdc (

    -- Business Columns
    product_id BIGINT,
    product_name STRING,
    product_description STRING,
    product_price DECIMAL(10,2),
    product_image STRING,
    product_category_id BIGINT,

    -- CDC Event Metadata
    op STRING,                     -- INSERT / UPDATE / DELETE
    event_ts TIMESTAMP,
    is_deleted BOOLEAN,

    -- CDC Tracking
    -- change_version BIGINT,
    -- change_type STRING,

    -- Source Metadata
    source_system STRING,
    source_file_name STRING,

    -- Pipeline Metadata
    ingestion_ts TIMESTAMP,
    ingestion_dt DATE,
    batch_id INTEGER,
    run_id STRING,

    -- Optional Tracking
    record_hash STRING

)
USING DELTA;

# %%
# %sql
CREATE TABLE IF NOT EXISTS retails.silver.products_cleaned (

    -- Business Columns
    product_id BIGINT,
    product_name STRING,
    product_description STRING,
    product_price DECIMAL(10,2),
    product_image STRING,
    product_category_id BIGINT,

    -- CDC State
    is_deleted BOOLEAN,

    -- Source Metadata
    op STRING,                  -- INSERT / UPDATE / DELETE
    source_system STRING,
    source_file_name STRING,
    
    -- Pipeline Metadata
    ingestion_ts TIMESTAMP,
    ingestion_dt DATE,
    batch_id INTEGER,
    run_id STRING,

    -- Audit Columns
    created_ts TIMESTAMP,
    updated_ts TIMESTAMP,

    -- Optional Tracking
    record_hash STRING

)
USING DELTA;

# %%
# %sql
CREATE TABLE IF NOT EXISTS retails.silver.products_quarantine (

    -- Auto generated PK
    quarantine_id STRING,

    -- Business Columns
    product_id STRING,
    product_name STRING,
    product_description STRING,
    product_price STRING,
    product_image STRING,
    product_category_id STRING,

    -- Source Metadata
    op STRING,                  -- INSERT / UPDATE / DELETE
    source_system STRING,
    source_file_name STRING,

    -- Quarantine columns
    _rescued_data STRING,
    _corrupt_record STRING,
    quarantine_reason STRING,
    quarantine_status STRING,

    -- Pipeline Metadata
    ingestion_ts TIMESTAMP,
    ingestion_dt DATE,
    batch_id BIGINT,
    run_id STRING,

    -- Audit Columns
    created_ts TIMESTAMP,
    updated_ts TIMESTAMP,
    reprocessed_at TIMESTAMP

)
USING DELTA;

# %%
# %sql
CREATE TABLE IF NOT EXISTS retails.silver.customers_cdc (

    -- Business Columns
    customer_id BIGINT,
    customer_fname STRING,
    customer_lname STRING,
    customer_email STRING,
    customer_password STRING,
    customer_street STRING,
    customer_city STRING,
    customer_state STRING,
    customer_zipcode BIGINT,

    -- CDC Event Metadata
    op STRING,                     -- INSERT / UPDATE / DELETE
    event_ts TIMESTAMP,
    is_deleted BOOLEAN,

    -- CDC Tracking
    -- change_version BIGINT,
    -- change_type STRING,

    -- Source Metadata
    source_system STRING,
    source_file_name STRING,

    -- Pipeline Metadata
    ingestion_ts TIMESTAMP,
    ingestion_dt DATE,
    batch_id INTEGER,
    run_id STRING,

    -- Optional Tracking
    record_hash STRING

)
USING DELTA;

# %%
# %sql
CREATE TABLE IF NOT EXISTS retails.silver.customers_cleaned (

    customer_id BIGINT,
    customer_fname STRING,
    customer_lname STRING,
    customer_email STRING,
    customer_password STRING,
    customer_street STRING,
    customer_city STRING,
    customer_state STRING,
    customer_zipcode BIGINT,

    op STRING,
    is_deleted BOOLEAN,

    ingestion_ts TIMESTAMP,
    ingestion_dt DATE,

    source_system STRING,
    source_file_name STRING,

    batch_id BIGINT,
    run_id STRING,

    record_hash STRING,

    created_ts TIMESTAMP,
    updated_ts TIMESTAMP

)
USING DELTA;

# %%
# %sql
CREATE TABLE IF NOT EXISTS retails.silver.customers_quarantine (

    quarantine_id STRING,

    customer_id STRING,

    customer_fname STRING,
    customer_lname STRING,

    customer_email STRING,
    customer_password STRING,

    customer_street STRING,
    customer_city STRING,
    customer_state STRING,

    customer_zipcode STRING,

    op STRING,

    _rescued_data STRING,
    _corrupt_record STRING,

    quarantine_reason STRING,
    quarantine_status STRING,

    ingestion_ts TIMESTAMP,
    ingestion_dt DATE,

    source_system STRING,
    source_file_name STRING,

    batch_id BIGINT,
    run_id STRING,

    created_ts TIMESTAMP,
    updated_ts TIMESTAMP,
    reprocessed_at TIMESTAMP

)
USING DELTA;

# %%
# %sql
CREATE TABLE IF NOT EXISTS retails.silver.orders_cdc (

    -- Business Columns
    order_id BIGINT,
    order_date DATE,
    order_customer_id BIGINT,
    order_status STRING,

    -- CDC Event Metadata
    op STRING,                     -- INSERT / UPDATE / DELETE
    event_ts TIMESTAMP,
    is_deleted BOOLEAN,

    -- CDC Tracking
    -- change_version BIGINT,
    -- change_type STRING,

    -- Source Metadata
    source_system STRING,
    source_file_name STRING,

    -- Pipeline Metadata
    ingestion_ts TIMESTAMP,
    ingestion_dt DATE,
    batch_id INTEGER,
    run_id STRING,

    -- Optional Tracking
    record_hash STRING

)
USING DELTA;

# %%
# %sql
CREATE TABLE IF NOT EXISTS retails.silver.orders_cleaned (

    order_id BIGINT,

    order_date DATE,
    order_customer_id BIGINT,

    order_status STRING,

    op STRING,
    is_deleted BOOLEAN,

    ingestion_ts TIMESTAMP,
    ingestion_dt DATE,

    source_system STRING,
    source_file_name STRING,

    batch_id BIGINT,
    run_id STRING,

    record_hash STRING,

    created_ts TIMESTAMP,
    updated_ts TIMESTAMP

)
USING DELTA;

# %%
# %sql
CREATE TABLE IF NOT EXISTS retails.silver.orders_quarantine (

    quarantine_id STRING,

    order_id STRING,
    order_date STRING,

    order_customer_id STRING,
    order_status STRING,

    op STRING,

    _rescued_data STRING,
    _corrupt_record STRING,

    quarantine_reason STRING,
    quarantine_status STRING,

    ingestion_ts TIMESTAMP,
    ingestion_dt DATE,

    source_system STRING,
    source_file_name STRING,

    batch_id BIGINT,
    run_id STRING,

    created_ts TIMESTAMP,
    updated_ts TIMESTAMP,
    reprocessed_at TIMESTAMP

)
USING DELTA;

# %%
# %sql
CREATE TABLE IF NOT EXISTS retails.silver.order_items_cdc (

    -- Business Columns
    order_item_id BIGINT,
    order_item_order_id BIGINT,
    order_item_product_id BIGINT,
    order_item_quantity BIGINT,
    order_item_subtotal DECIMAL(10,2),
    order_item_product_price DECIMAL(10,2),

    -- CDC Event Metadata
    op STRING,                     -- INSERT / UPDATE / DELETE
    event_ts TIMESTAMP,
    is_deleted BOOLEAN,

    -- CDC Tracking
    -- change_version BIGINT,
    -- change_type STRING,

    -- Source Metadata
    source_system STRING,
    source_file_name STRING,

    -- Pipeline Metadata
    ingestion_ts TIMESTAMP,
    ingestion_dt DATE,
    batch_id INTEGER,
    run_id STRING,

    -- Optional Tracking
    record_hash STRING

)
USING DELTA;

# %%
# %sql
CREATE TABLE IF NOT EXISTS retails.silver.order_items_cleaned (

    order_item_id BIGINT,
    order_item_order_id BIGINT,
    order_item_product_id BIGINT,

    order_item_quantity BIGINT,

    order_item_subtotal DECIMAL(10,2),
    order_item_product_price DECIMAL(10,2),

    op STRING,
    is_deleted BOOLEAN,

    ingestion_ts TIMESTAMP,
    ingestion_dt DATE,

    source_system STRING,
    source_file_name STRING,

    batch_id BIGINT,
    run_id STRING,

    record_hash STRING,

    created_ts TIMESTAMP,
    updated_ts TIMESTAMP

)
USING DELTA;

# %%
# %sql
CREATE TABLE IF NOT EXISTS retails.silver.order_items_quarantine (

    quarantine_id STRING,

    order_item_id STRING,
    order_item_order_id STRING,
    order_item_product_id STRING,

    order_item_quantity STRING,

    order_item_subtotal STRING,
    order_item_product_price STRING,

    op STRING,

    _rescued_data STRING,
    _corrupt_record STRING,

    quarantine_reason STRING,
    quarantine_status STRING,

    ingestion_ts TIMESTAMP,
    ingestion_dt DATE,

    source_system STRING,
    source_file_name STRING,

    batch_id BIGINT,
    run_id STRING,

    created_ts TIMESTAMP,
    updated_ts TIMESTAMP,
    reprocessed_at TIMESTAMP

)
USING DELTA;

# %%
# %sql
CREATE TABLE IF NOT EXISTS retails.silver.cdc_rejected_events (

    reject_id STRING,

    entity_name STRING,
    business_key STRING,

    op STRING,

    reject_reason STRING,

    payload STRING,

    ingestion_ts TIMESTAMP,
    ingestion_dt DATE,

    source_system STRING,
    source_file_name STRING,

    batch_id BIGINT,
    run_id STRING,

    created_ts TIMESTAMP

)
USING DELTA;

# %%
# GRANTS = "ALTER TABLE retails.silver.products_cdc OWNER TO `dp-sales-engineers`"
# spark.sql(GRANTS).display()

# %%
# %sql
show tables in retails.silver;
