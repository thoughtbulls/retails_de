# %% [markdown]
# retails db data convert from csv to json

# %%
schema = """
    category_id INTEGER,
    category_department_id INTEGER,
    category_name STRING
    """

df = spark.read \
        .format("csv") \
        .schema(schema) \
        .option("inferSchema", "true") \
        .load("dbfs:/Volumes/workspace/retails/raw_data/csv/categories/")

# %%
df.printSchema()

# %%
display(df)

# %%
df.write \
.format("json") \
.mode("overwrite") \
.save("dbfs:/Volumes/workspace/retails/raw_data/json/categories/")

# %%
# dbutils.fs.ls("dbfs:/Volumes/workspace/retails/raw_data/json/")

json_df = spark.read \
.format("json") \
.load("dbfs:/Volumes/workspace/retails/raw_data/json/categories/")

# %%
display(json_df)
